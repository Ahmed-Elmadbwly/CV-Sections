# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %%
model = YOLO("yolo11m.pt")

path = "1.jpg"
results = model(source=path,conf=0.4)
# Out:
# image 1/1 D:\FCI\CV\CV-Sections\section5\yolo_with_image\1.jpg: 480x640 7 persons, 3 ties, 859.5ms
# Speed: 5.0ms preprocess, 859.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
result_img = results[0].plot()  
plt.imshow(result_img)
plt.axis('off')
plt.show()
